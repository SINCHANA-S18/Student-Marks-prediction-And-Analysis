# 13   14  6.58  6.58  9.20  5.87  7.59
# 14   15  6.58  9.20  9.20  6.45  6.58
# 15   16  6.58  9.20  9.20  8.27  7.56
# 16   17  6.58  9.20  9.20  8.27  8.82
# 17   18  6.58  9.20  9.20  8.27  8.82
# 18   19  6.58  9.20  0.00  8.27  8.82
# 19   20  6.58  9.20  8.27  6.58  8.82
# 20   21  6.58  9.20  8.27  6.58  9.01
# 21   22  6.58  9.20  8.27  6.58  5.57
# 22   23  7.25  9.20  8.27  6.58  5.57
# 23   24  7.25  9.20  0.00  6.58  5.57
# 24   25  7.25  5.60  6.58  6.58  7.59
# 25   26  7.25  5.60  6.58  6.58  7.59
# 26   27  7.25  5.60  6.58  6.58  7.59
# 27   28  7.25  5.60  6.58  6.58  8.82
# 28   29  8.89  5.60  6.58  6.58  8.82
# 29   30  8.89  5.60  6.58  6.73  8.82
# 30   31  8.89  7.25  6.58  9.20  8.82
# 31   32  8.89  7.25  6.58  9.20  7.89
# 32   33  8.89  7.25  6.58  9.20  6.38
# 33   34  0.00  0.00  6.58  9.20  8.89
# 34   35  5.60  8.89  7.25  9.20  7.59
# 35   36  5.60  8.89  7.25  9.20  7.59
# 36   37  5.60  8.89  7.25  9.20  7.59
# 37   38  5.60  8.89  7.25  9.20  5.57
# 38   39  5.60  8.89  7.25  9.20  5.57
# 39   40  5.60  0.00  7.25  9.20  5.57

# %%
data=data.dropna(how='any')

# %%
df_less = data[(data['cg1']<1) | (data['cg2']<1) | (data['cg3']<1) | (data['cg4']<1) | (data['cg5']<1) ]
print(type(df_less))
df_less
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     usn   cg1   cg2   cg3   cg4   cg5
# 6     7  9.20  6.58  9.20  0.00  5.57
# 12   13  6.58  6.58  9.20  0.00  7.59
# 18   19  6.58  9.20  0.00  8.27  8.82
# 23   24  7.25  9.20  0.00  6.58  5.57
# 33   34  0.00  0.00  6.58  9.20  8.89
# 39   40  5.60  0.00  7.25  9.20  5.57

# %%
df_less = data[(data['cg1']<1) | (data['cg2']<1) | (data['cg3']<1) | (data['cg4']<1) | (data['cg5']<1) ].index
print(type(df_less))
print(df_less)
# Out:
# <class 'pandas.core.indexes.numeric.Int64Index'>
# Int64Index([6, 12, 18, 23, 33, 39], dtype='int64')

# %%
plt.figure(figsize=(10,10))

plt.scatter(data['cg1'],data['cg2'])
plt.xlabel('1st Sem CGPA')
plt.ylabel('2nd Sem CGPA')

plt.grid()
plt.show()

# %%
sns.displot(data['cg4']- data['cg3'])

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
X = data.drop('cg5',axis=1)
y = data['cg5']
print(X)
print(y)
# Out:
#     usn   cg1   cg2   cg3   cg4
# 0     1  9.20  8.27  8.89  7.25
# 1     2  9.20  8.27  8.89  7.25
# 2     3  9.20  8.27  8.89  7.25
# 3     4  9.20  8.27  8.89  7.25
# 4     5  9.20  6.58  8.89  7.25
# 5     6  9.20  6.58  9.20  7.25
# 6     7  9.20  6.58  9.20  0.00
# 7     8  9.20  6.58  9.20  8.89
# 8     9  8.27  6.58  9.20  8.89
# 9    10  8.27  6.58  9.20  8.89
# 10   11  8.27  6.58  9.20  8.89
# 11   12  8.27  6.58  9.20  8.89
# 12   13  6.58  6.58  9.20  0.00
# 13   14  6.58  6.58  9.20  5.87
# 14   15  6.58  9.20  9.20  6.45
# 15   16  6.58  9.20  9.20  8.27
# 16   17  6.58  9.20  9.20  8.27
# 17   18  6.58  9.20  9.20  8.27
# 18   19  6.58  9.20  0.00  8.27
# 19   20  6.58  9.20  8.27  6.58
# 20   21  6.58  9.20  8.27  6.58
# 21   22  6.58  9.20  8.27  6.58
# 22   23  7.25  9.20  8.27  6.58
# 23   24  7.25  9.20  0.00  6.58
# 24   25  7.25  5.60  6.58  6.58
# 25   26  7.25  5.60  6.58  6.58
# 26   27  7.25  5.60  6.58  6.58
# 27   28  7.25  5.60  6.58  6.58
# 28   29  8.89  5.60  6.58  6.58
# 29   30  8.89  5.60  6.58  6.73
# 30   31  8.89  7.25  6.58  9.20
# 31   32  8.89  7.25  6.58  9.20
# 32   33  8.89  7.25  6.58  9.20
# 33   34  0.00  0.00  6.58  9.20
# 34   35  5.60  8.89  7.25  9.20
# 35   36  5.60  8.89  7.25  9.20
# 36   37  5.60  8.89  7.25  9.20
# 37   38  5.60  8.89  7.25  9.20
# 38   39  5.60  8.89  7.25  9.20
# 39   40  5.60  0.00  7.25  9.20
# 0     8.82
# 1     8.82
# 2     8.82
# 3     8.82
# 4     8.01
# 5     7.98
# 6     5.57
# 7     5.57
# 8     5.57
# 9     6.48
# 10    8.63
# 11    7.59
# 12    7.59
# 13    7.59
# 14    6.58
# 15    7.56
# 16    8.82
# 17    8.82
# 18    8.82
# 19    8.82
# 20    9.01
# 21    5.57
# 22    5.57
# 23    5.57
# 24    7.59
# 25    7.59
# 26    7.59
# 27    8.82
# 28    8.82
# 29    8.82
# 30    8.82
# 31    7.89
# 32    6.38
# 33    8.89
# 34    7.59
# 35    7.59
# 36    7.59
# 37    5.57
# 38    5.57
# 39    5.57
# Name: cg5, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.1, random_state=101)

# %%
# creating a regression model
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

# %%
print(predictions)
print(y_test)
# Out:
# [7.31005892 7.49601778 7.04370278 7.35004397]
# 18    8.82
# 16    8.82
# 36    7.59
# 25    7.59
# Name: cg5, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
# model evaluation
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  1.0972176357929533
# mean_absolute_error :  0.905044139504801

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
#import re
import random
import seaborn as sns

# %%
data=pd.read_csv('/content/drive/MyDrive/6th sem..csv')

# %%
col=['usn','cg1','cg2','cg3','cg4','cg5']
data.columns=col

# %%
data
# Out:
#             usn   cg1    cg2   cg3   cg4   cg5
# 0    1GA20CS001  1.48   0.00  0.00  0.00  0.00
# 1    1GA20CS002  8.33   8.84  7.63  7.58  0.00
# 2    1GA20CS003  6.33   7.00  6.92  7.29  7.96
# 3    1GA20CS004  7.48   8.21  7.79  7.00  7.65
# 4    1GA20CS005  9.43  10.00  9.50  9.29  8.00
# ..          ...   ...    ...   ...   ...   ...
# 202  1GA21CS416  0.00   0.00  6.00  7.29  0.00
# 203  1GA21CS410  0.00   0.00  3.88  5.58  0.00
# 204  1GA21CS401  0.00   0.00  7.25  5.67  0.00
# 205  1GA21CS402  0.00   0.00  2.38  8.53  0.00
# 206  1GA21CS412  0.00   0.00  6.17  7.21  0.00
#
# [207 rows x 6 columns]

# %%
data.shape
# Out:
# (207, 6)

# %%
data.head()
# Out:
#           usn   cg1    cg2   cg3   cg4   cg5
# 0  1GA20CS001  1.48   0.00  0.00  0.00  0.00
# 1  1GA20CS002  8.33   8.84  7.63  7.58  0.00
# 2  1GA20CS003  6.33   7.00  6.92  7.29  7.96
# 3  1GA20CS004  7.48   8.21  7.79  7.00  7.65
# 4  1GA20CS005  9.43  10.00  9.50  9.29  8.00

# %%
data.tail()
# Out:
#             usn  cg1  cg2   cg3   cg4  cg5
# 202  1GA21CS416  0.0  0.0  6.00  7.29  0.0
# 203  1GA21CS410  0.0  0.0  3.88  5.58  0.0
# 204  1GA21CS401  0.0  0.0  7.25  5.67  0.0
# 205  1GA21CS402  0.0  0.0  2.38  8.53  0.0
# 206  1GA21CS412  0.0  0.0  6.17  7.21  0.0

# %%
data.describe()
# Out:
#               cg1         cg2         cg3         cg4          cg5
# count  207.000000  207.000000  207.000000  207.000000   207.000000
# mean     6.380531    6.720097    7.215749    7.652271   131.336087
# std      3.203858    3.417762    2.183464    2.225383  1041.241709
# min      0.000000    0.000000    0.000000    0.000000     0.000000
# 25%      5.850000    6.210000    6.520000    7.210000     0.000000
# 50%      7.380000    8.110000    7.880000    8.420000     7.780000
# 75%      8.615000    8.920000    8.650000    9.080000     8.980000
# max     10.000000   10.000000    9.880000   10.000000  9022.000000

# %%
data=data.replace(to_replace="nil",
           value=0)

# %%
data=data.replace(to_replace = np.nan, value =0)
data
# Out:
#             usn   cg1    cg2   cg3   cg4   cg5
# 0    1GA20CS001  1.48   0.00  0.00     0     0
# 1    1GA20CS002  8.33   8.84  7.63  7.58     0
# 2    1GA20CS003  6.33   7.00  6.92  7.29  7.96
# 3    1GA20CS004  7.48   8.21  7.79     7  7.65
# 4    1GA20CS005  9.43  10.00  9.50  9.29     8
# ..          ...   ...    ...   ...   ...   ...
# 202  1GA21CS416  0.00   0.00  6.00  7.29     0
# 203  1GA21CS410  0.00   0.00  3.88  5.58     0
# 204  1GA21CS401  0.00   0.00  7.25  5.67     0
# 205  1GA21CS402  0.00   0.00  2.38  8.53     0
# 206  1GA21CS412  0.00   0.00  6.17  7.21     0
#
# [207 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   usn     207 non-null    object
#  1   cg1     207 non-null    float64
#  2   cg2     207 non-null    float64
#  3   cg3     207 non-null    float64
#  4   cg4     207 non-null    float64
#  5   cg5     207 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 9.8+ KB

# %%
df_less = data[(data['cg1']<1) | (data['cg2']<1) | (data['cg3']<1) | (data['cg4']<1) | (data['cg5']<1) ]
print(type(df_less))
df_less
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             usn   cg1   cg2   cg3   cg4   cg5
# 0    1GA20CS001  1.48  0.00  0.00  0.00  0.00
# 1    1GA20CS002  8.33  8.84  7.63  7.58  0.00
# 5    1GA20CS006  4.12  0.00  1.25  1.63  9.35
# 9    1GA20CS010  5.27  5.32  2.50  0.96  8.78
# 17   1GA20CS018  0.00  0.00  0.00  0.00  9.87
# ..          ...   ...   ...   ...   ...   ...
# 202  1GA21CS416  0.00  0.00  6.00  7.29  0.00
# 203  1GA21CS410  0.00  0.00  3.88  5.58  0.00
# 204  1GA21CS401  0.00  0.00  7.25  5.67  0.00
# 205  1GA21CS402  0.00  0.00  2.38  8.53  0.00
# 206  1GA21CS412  0.00  0.00  6.17  7.21  0.00
#
# [72 rows x 6 columns]

# %%
data.shape
# Out:
# (207, 6)

# %%
df_less = data[(data['cg1']<1) | (data['cg2']<1) | (data['cg3']<1) | (data['cg4']<1) | (data['cg5']<1) ]
print(type(df_less))
df_less
# Out:
# <class 'pandas.core.frame.DataFrame'>
#             usn   cg1   cg2   cg3   cg4   cg5
# 0    1GA20CS001  1.48  0.00  0.00  0.00  0.00
# 1    1GA20CS002  8.33  8.84  7.63  7.58  0.00
# 5    1GA20CS006  4.12  0.00  1.25  1.63  9.35
# 9    1GA20CS010  5.27  5.32  2.50  0.96  8.78
# 17   1GA20CS018  0.00  0.00  0.00  0.00  9.87
# ..          ...   ...   ...   ...   ...   ...
# 202  1GA21CS416  0.00  0.00  6.00  7.29  0.00
# 203  1GA21CS410  0.00  0.00  3.88  5.58  0.00
# 204  1GA21CS401  0.00  0.00  7.25  5.67  0.00
# 205  1GA21CS402  0.00  0.00  2.38  8.53  0.00
# 206  1GA21CS412  0.00  0.00  6.17  7.21  0.00
#
# [72 rows x 6 columns]

# %%
df_less = data[(data['cg1']<1) | (data['cg2']<1) | (data['cg3']<1) | (data['cg4']<1) | (data['cg5']<1) ].index
print(type(df_less))
print(df_less)
# Out:
# <class 'pandas.core.indexes.numeric.Int64Index'>
# Int64Index([  0,   1,   5,   9,  17,  29,  38,  52,  53,  69,  76,  79, 115,
#             141, 149, 150, 151, 152, 153, 154, 155, 156, 157, 158, 159, 160,
#             161, 162, 163, 164, 165, 166, 167, 168, 169, 170, 171, 172, 173,
#             174, 175, 176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186,
#             187, 188, 189, 190, 191, 192, 193, 194, 195, 196, 197, 198, 199,
#             200, 201, 202, 203, 204, 205, 206],
#            dtype='int64')

# %%
plt.figure(figsize=(10,10))

plt.scatter(data['cg1'],data['cg2'])
plt.xlabel('1st Sem CGPA')
plt.ylabel('2nd Sem CGPA')

plt.grid()
plt.show()

# %%
sns.displot(data['cg4']- data['cg3'])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
X = data.drop(['usn','cg5'],axis=1)
y = data['cg5']
print(X)
print(y)
# Out:
#       cg1    cg2   cg3   cg4
# 0    1.48   0.00  0.00  0.00
# 1    8.33   8.84  7.63  7.58
# 2    6.33   7.00  6.92  7.29
# 3    7.48   8.21  7.79  7.00
# 4    9.43  10.00  9.50  9.29
# ..    ...    ...   ...   ...
# 202  0.00   0.00  6.00  7.29
# 203  0.00   0.00  3.88  5.58
# 204  0.00   0.00  7.25  5.67
# 205  0.00   0.00  2.38  8.53
# 206  0.00   0.00  6.17  7.21
#
# [207 rows x 4 columns]
# 0      0.00
# 1      0.00
# 2      7.96
# 3      7.65
# 4      8.00
#        ...
# 202    0.00
# 203    0.00
# 204    0.00
# 205    0.00
# 206    0.00
# Name: cg5, Length: 207, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1)

# %%
# creating a regression model
model = LinearRegression()

# %%
model.fit(X_train,y_train)
predictions = model.predict(X_test)

# %%
print(predictions)
print(y_test)
# Out:
# [   3.53875064  191.5251069   191.64134105 -180.48413876  219.21332685
#   136.59086671  161.13155555  283.63949277   55.60330711  175.22404923
#   145.11413022  173.10777036  179.15903908  321.68793175  152.58058386
#   169.69344704  143.50141319  171.25949295  109.34091455  157.48221172
#   -15.85762837  145.37926884  203.27225736   13.66555519  186.77343178
#   163.31818841  141.40993304  181.77654269  177.82516279  184.45429937
#   178.72161353   -2.26789466  124.87033656  145.30178474  121.64776121
#   152.14782484 -287.26194036  127.99022695   61.68230791  135.84882729
#    41.97710701  189.48555916  131.09626157  157.51769906  135.08536201
#    49.91137495  403.2422758   244.81823583  165.46831063  132.80420261
#   153.23513261  185.68469952  175.27034793  166.2688289   218.19146068
#    23.54830009    4.91786468  140.48683098  211.5605125   157.50867266
#   224.86545374  169.63457535  180.5503333 ]
# 186    0.00
# 155    0.00
# 165    0.00
# 200    0.00
# 58     8.87
#        ...
# 88     8.30
# 39     6.43
# 114    8.74
# 132    9.26
# 56     9.26
# Name: cg5, Length: 63, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing
# model evaluation
print(
  'mean_squared_error : ', mean_squared_error(y_test, predictions))
print(
  'mean_absolute_error : ', mean_absolute_error(y_test, predictions))
# Out:
# mean_squared_error :  1277998.1731045148
# mean_absolute_error :  288.1937585826069
